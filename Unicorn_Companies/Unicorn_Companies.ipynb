# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\asus\OneDrive\Desktop\Python Project\Unicorn_Companies\Unicorn.Companies.csv")

# %%
df
# Out:
#           Company Valuation Date Joined                         Industry  \
# 0       Bytedance     $180B  2017-04-07          Artificial intelligence
# 1          SpaceX     $100B  2012-12-01                            Other
# 2           SHEIN     $100B  2018-07-03  E-commerce & direct-to-consumer
# 3          Stripe      $95B  2014-01-23                          Fintech
# 4          Klarna      $46B  2011-12-12                          Fintech
# ...           ...       ...         ...                              ...
# 1069     Zhaogang       $1B  2017-06-29  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan       $1B  2017-04-18  E-commerce & direct-to-consumer
# 1071     Zihaiguo       $1B  2021-05-06                Consumer & retail
# 1072         Zopa       $1B  2021-10-19                          Fintech
# 1073        Zwift       $1B  2020-09-16  E-commerce & direct-to-consumer
#
#                City         Country      Continent  Year Founded Funding  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   object
#  2   Date Joined       1074 non-null   object
#  3   Industry          1074 non-null   object
#  4   City              1058 non-null   object
#  5   Country           1074 non-null   object
#  6   Continent         1074 non-null   object
#  7   Year Founded      1074 non-null   int64
#  8   Funding           1074 non-null   object
#  9   Select Investors  1073 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 84.0+ KB

# %%
df.isnull().sum()
# Out:
# Company              0
# Valuation            0
# Date Joined          0
# Industry             0
# City                16
# Country              0
# Continent            0
# Year Founded         0
# Funding              0
# Select Investors     1
# dtype: int64

# %%
type(df["Valuation"][0])
# Out:
# str

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# For Replacing $ and B with 0000000000

# %%
l=[]
for i in df["Valuation"]:
    l.append(int(i[1:-1]+"000000000"))

# %%
len(l)
# Out:
# 1074

# %%
df["Valuation"]=l

# %% [markdown]
# For Replacing $ and B with 000000000 and M with 000000

# %%
l=[]
for i in df["Funding"]:
    if "B" in i:
        l.append(int(i[1:-1]+"000000000"))
    elif "M" in i:
        l.append(int(i[1:-1]+"000000"))
    else:
        l.append(None)

# %%
l
# Out:
# [8000000000,
#  7000000000,
#  2000000000,
#  2000000000,
#  4000000000,
#  572000000,
#  2000000000,
#  3000000000,
#  14000000000,
#  3000000000,
#  2000000000,
#  7000000000,
#  2000000000,
#  4000000000,
#  2000000000,
#  4000000000,
#  5000000000,
#  918000000,
#  476000000,
#  4000000000,
#  770000000,
#  979000000,
#  721000000,
#  3000000000,
#  490000000,
#  734000000,
#  2000000000,
#  427000000,
#  400000000,
#  4000000000,
#  4000000000,
#  1000000000,
#  1000000000,
#  1000000000,
#  2000000000,
#  799000000,
#  765000000,
#  800000000,
#  5000000000,
#  376000000,
#  1000000000,
#  5000000000,
#  558000000,
#  5000000000,
#  1000000000,
#  1000000000,
#  3000000000,
#  294000000,
#  3000000000,
#  572000000,
#  1000000000,
#  564000000,
#  4000000000,
#  1000000000,
#  333000000,
#  691000000,
#  2000000000,
#  343000000,
#  1000000000,
#  497000000,
#  2000000000,
#  71000000,
#  2000000000,
#  1000000000,
#  2000000000,
#  1000000000,
#  2000000000,
#  2000000000,
# ...

# %%
for i in df["Funding"]:
    if "M" not in i and "B" not in i:
        print(i)
# Out:
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown

# %%
df["Funding"]=l

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   int64
#  2   Date Joined       1074 non-null   object
#  3   Industry          1074 non-null   object
#  4   City              1058 non-null   object
#  5   Country           1074 non-null   object
#  6   Continent         1074 non-null   object
#  7   Year Founded      1074 non-null   int64
#  8   Funding           1062 non-null   float64
#  9   Select Investors  1073 non-null   object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 84.0+ KB

# %% [markdown]
# Removing Null Values

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1045 entries, 0 to 1073
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1045 non-null   object
#  1   Valuation         1045 non-null   int64
#  2   Date Joined       1045 non-null   object
#  3   Industry          1045 non-null   object
#  4   City              1045 non-null   object
#  5   Country           1045 non-null   object
#  6   Continent         1045 non-null   object
#  7   Year Founded      1045 non-null   int64
#  8   Funding           1045 non-null   float64
#  9   Select Investors  1045 non-null   object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 89.8+ KB

# %% [markdown]
# Unicorn Companies:
#
# Private companies with a valuation over $1 billion as of March 2022, including each
# company's current valuation, funding, country of origin, industry, select investors, and
# the years they were founded and became unicorns.
# Recommended Analysis
#
#
# 1. Which unicorn companies have had the biggest return on investment?
# 2. How long does it usually take for a company to become a unicorn? Has it
# always been this way?
# 3. Which countries have the most unicorns? Are there any cities that appear to
# be industry hubs?
# 4. Which investors have funded the most unicorns?

# %% [markdown]
# For finding ROI

# %%
l=[]
for i,j in zip(df["Valuation"],df["Funding"]):
    l.append(i-j)

# %%
df["ROI"]=l

# %%
df
# Out:
#           Company     Valuation Date Joined                         Industry  \
# 0       Bytedance  180000000000  2017-04-07          Artificial intelligence
# 1          SpaceX  100000000000  2012-12-01                            Other
# 2           SHEIN  100000000000  2018-07-03  E-commerce & direct-to-consumer
# 3          Stripe   95000000000  2014-01-23                          Fintech
# 4          Klarna   46000000000  2011-12-12                          Fintech
# ...           ...           ...         ...                              ...
# 1069     Zhaogang    1000000000  2017-06-29  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan    1000000000  2017-04-18  E-commerce & direct-to-consumer
# 1071     Zihaiguo    1000000000  2021-05-06                Consumer & retail
# 1072         Zopa    1000000000  2021-10-19                          Fintech
# 1073        Zwift    1000000000  2020-09-16  E-commerce & direct-to-consumer
#
# ...

# %%
df1=df.sort_values("ROI",ascending=False)

# %%
plt.bar(df1["Company"][:10],df1["ROI"][:10])
f={"size":15,"color":"blue","family":"Times New Roman"}
f1={"size":20,"color":"black","family":"Times New Roman"}
plt.xlabel("Unicorn Name",fontdict=f)
plt.ylabel("Return on Investment",fontdict=f)
plt.title("Unicorn Companies having biggest return",fontdict=f1)
plt.xticks(rotation=60)
plt.rcParams["figure.figsize"]=(7,5)
plt.show()

# %%
l=[]
for i,j in zip(df["Date Joined"],df["Year Founded"]):
    l.append(int(i[:4])-j)

# %%
df["Year Taken"]=l

# %%
df1=df.sort_values("Year Taken")

# %%
df1.head(10)
# Out:
#                     Company   Valuation Date Joined  \
# 714            Yidian Zixun  1000000000  2017-10-17
# 1001                 Playco  1000000000  2020-09-21
# 546                   Avant  2000000000  2012-12-17
# 161   Ola Electric Mobility  5000000000  2019-07-02
# 314              Flink Food  3000000000  2021-12-01
# 554              ClickHouse  2000000000  2021-10-28
# 822              GlobalBees  1000000000  2021-12-28
# 967            Mensa Brands  1000000000  2021-11-16
# 396               candy.com  2000000000  2021-10-21
# 775                    Jokr  1000000000  2021-12-02
#
#                              Industry            City        Country  \
# 714       Mobile & telecommunications         Beijing          China
# 1001                            Other           Tokyo          Japan
# 546           Artificial intelligence         Chicago  United States
# 161             Auto & transportation       Bengaluru          India
# ...

# %%
plt.bar(df1["Company"][1:11],df1["Year Taken"][1:11])
f={"size":15,"color":"blue","family":"Times New Roman"}
f1={"size":20,"color":"black","family":"Times New Roman"}
plt.xlabel("Unicorn Name",fontdict=f)
plt.ylabel("Year Taken to become Unicorn",fontdict=f)
plt.title("Fastest Unicorns",fontdict=f1)
plt.xticks(rotation=60)
plt.rcParams["figure.figsize"]=(7,5)
plt.show()

# %%
plt.bar(df1["Company"].tail(10),df1["Year Taken"].tail(10))
f={"size":15,"color":"blue","family":"Times New Roman"}
f1={"size":20,"color":"black","family":"Times New Roman"}
plt.xlabel("Unicorn Name",fontdict=f)
plt.ylabel("Year Taken to become Unicorn",fontdict=f)
plt.title("Slowest Unicorns",fontdict=f1)
plt.xticks(rotation=60)
plt.rcParams["figure.figsize"]=(7,5)
plt.show()

# %%
l=df["Country"].unique()

# %%
l
# Out:
# array(['China', 'United States', 'Sweden', 'Australia', 'United Kingdom',
#        'India', 'Indonesia', 'Turkey', 'Estonia', 'Germany', 'Hong Kong',
#        'South Korea', 'Mexico', 'Canada', 'Netherlands', 'France',
#        'Finland', 'Israel', 'Lithuania', 'Denmark', 'Belgium', 'Colombia',
#        'Brazil', 'Austria', 'Ireland', 'United Arab Emirates',
#        'Switzerland', 'Vietnam', 'South Africa', 'Thailand', 'Norway',
#        'Chile', 'Argentina', 'Bermuda', 'Japan', 'Spain', 'Malaysia',
#        'Senegal', 'Philippines', 'Luxembourg', 'Nigeria',
#        'Czech Republic', 'Croatia', 'Italy'], dtype=object)

# %%
l1=[]
for i in l:
    l1.append(df["Company"].where(df["Country"]==i).count())

# %%
df1=pd.DataFrame({"Country":l,"No. of Unicorns":l1})
df1=df1.sort_values("No. of Unicorns",ascending=False)
df1
# Out:
#                  Country  No. of Unicorns
# 1          United States              555
# 0                  China              169
# 5                  India               65
# 4         United Kingdom               43
# 9                Germany               26
# 15                France               23
# 17                Israel               20
# 13                Canada               18
# 22                Brazil               16
# 11           South Korea               12
# 3              Australia                8
# 12                Mexico                6
# 14           Netherlands                6
# 6              Indonesia                6
# 2                 Sweden                6
# 26           Switzerland                5
# 34                 Japan                5
# 24               Ireland                5
# 30                Norway                4
# 16               Finland                4
# 35                 Spain                3
# ...

# %%
plt.bar(df1["Country"][:10],df1["No. of Unicorns"][:10])
f={"size":15,"color":"blue","family":"Times New Roman"}
f1={"size":20,"color":"black","family":"Times New Roman"}
plt.xlabel("Country",fontdict=f)
plt.ylabel("No. of Unicorns",fontdict=f)
plt.title("Country Wise No. of Unicorns",fontdict=f1)
plt.xticks(rotation=60)
plt.rcParams["figure.figsize"]=(7,5)
plt.show()
